# %%
import numpy as np 
import matplotlib.pyplot as plt 
from PIL import Image , ImageChops ,ImageFilter

# %%
img = Image.open('images.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=554x554>

# %%
img.mode
# Out:
# 'RGB'

# %%
img_array = np.array(img)
img_array.shape
# Out:
# (554, 554, 3)

# %%
type(img_array)
# Out:
# numpy.ndarray

# %%
img1 = img_array.copy()

# %%
#img1[:,:,0] = 0

# %%
#plt.imshow(img1)

# %%
##img1[:,:,1] = 0

# %%
#plt.imshow(img1)

# %%
img1[:,:,2] = 0

# %%
plt.imshow(img1)

# %%
img2 = img_array.copy()

# %%
img2[:,:,0]=255

# %%
plt.imshow(img2)

# %%
img2[:,:,1]=255

# %%
plt.imshow(img2)

# %% [markdown]
# img2[:,:,2]=255
# plt.imshow(img2)

# %%
img3=img_array.copy()
img3[:,:,0]=50
img3[:,:,1]=150
img3[:,:,2]=200

# %%
plt.imshow(img3)

# %%
x = Image.open('x.png')

# %%
plt.imshow(x)

# %%
o = Image.open('o.png')
plt.imshow(o)

# %%
print('size of image x is ' , x.size , 'color mode ' , x.mode)
print('size of image o is ' , o.size , 'color mode ' , o.mode)
# Out:
# size of image x is  (256, 256) color mode  RGB
# size of image o is  (256, 256) color mode  RGB

# %%
#x = x.convert("RGB")
#o = o.convert("RGB")

# %%
#o = o.resize(x.size)

# %%
#merged = ImageChops.multiply(x,o)
#print(merged)
#plt.imshow(merged)

# %%
#addition = ImageChops.add(x,o)
#print(addition)
#plt.imshow(addition)

# %%
#plot 2 images one besides other 
plt.subplot(121) , plt.show(x)
plt.axis('off')
plt.subplot(122) , plt.show(o)
plt.axis('off')
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %%
#image basics 
#reading an image 
#playing with rgb channels 
#image resizing 
##cropping the image 
#rotation
#normalization

# %%
import cv2
print(cv2.__version__)
print("Open cv working ... let's go now💋 ")
# Out:
# 5.0.0
# Open cv working ... let's go now💋

# %%
#0 is black 255 is white and in between the colors are geryscale 
#colored images we use 3 channels are basically RGB (red , green , blue )
#image resolution i.e. full hd (1420*1080) which means there are total 1420 pixels in column and 1080 row pixels and total is their multiplication

# %%
# TO create an image  and how to read an image 
photo = cv2.imread("x.png")
print(type(photo))
print(photo.shape)
print(photo)
cv2.imshow("MAC",photo)
#cv2.waitKey(0)
# Out:
# <class 'numpy.ndarray'>
# (256, 256, 3)
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
#readanimage
print(type(photo))
print(photo.shape)
cv2.imshow("MAC",photo)
# Out:
# <class 'numpy.ndarray'>
# (256, 256, 3)

# %%
grey = cv2.cvtColor(photo,cv2.COLOR_BGR2GRAY)
print(grey.shape)
grey
# Out:
# (256, 256)
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], shape=(256, 256), dtype=uint8)
