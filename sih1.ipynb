# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from PIL import Image 
import os

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'images.jpeg',
#  'Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network',
#  'sih1.ipynb',
#  'sih2ImageClassificationpart.ipynb']

# %%
print(os.path)
# Out:
# <module 'posixpath' (frozen)>

# %%
items = os.listdir()
print(items)
# Out:
# ['.DS_Store', 'images.jpeg', 'Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network', 'sih1.ipynb', 'sih2ImageClassificationpart.ipynb']

# %%
current_folder = os.getcwd()
print(current_folder)
# Out:
# /Users/rishikamishra/Documents/MeraKaamMember1

# %%
for item in items:
     path = os.path.join(current_folder, item)
     if os.path.isfile(path):
         print(item , " = File")
     elif os.path.isdir(path):
         print(item," = Directory")
# Out:
# .DS_Store  = File
# images.jpeg  = File
# Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network  = Directory
# sih1.ipynb  = File
# sih2ImageClassificationpart.ipynb  = File

# %%
os.getcwd()
# Out:
# '/Users/rishikamishra/Documents/MeraKaamMember1'

# %%
os.chdir('/Users/rishikamishra/Documents/MeraKaamMember1')

# %%
os.getcwd()
# Out:
# '/Users/rishikamishra/Documents/MeraKaamMember1'

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'images.jpeg',
#  'Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network',
#  'sih1.ipynb',
#  'sih2ImageClassificationpart.ipynb']

# %%
os.chdir("Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network")

# %%
os.getcwd()
# Out:
# '/Users/rishikamishra/Documents/MeraKaamMember1/Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network'

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'Plant_leave_diseases_dataset_with_augmentation',
#  'Plant_leave_diseases_dataset_without_augmentation']

# %%
os.chdir('Plant_leave_diseases_dataset_without_augmentation')

# %%
os.getcwd()
# Out:
# '/Users/rishikamishra/Documents/MeraKaamMember1/Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network/Plant_leave_diseases_dataset_without_augmentation'

# %%
os.listdir()
# Out:
# ['Strawberry___healthy',
#  'Grape___Black_rot',
#  'Potato___Early_blight',
#  'Blueberry___healthy',
#  'Cherry___Powdery_mildew',
#  'Tomato___Target_Spot',
#  '.DS_Store',
#  'Peach___healthy',
#  'Potato___Late_blight',
#  'Tomato___Late_blight',
#  'Tomato___Tomato_mosaic_virus',
#  'Pepper,_bell___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Tomato___Leaf_Mold',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Apple___Cedar_apple_rust',
#  'Tomato___Bacterial_spot',
#  'Grape___healthy',
#  'Corn___Cercospora_leaf_spot Gray_leaf_spot',
#  'Tomato___Early_blight',
#  'Grape___Esca_(Black_Measles)',
#  'Raspberry___healthy',
#  'Tomato___healthy',
#  'Corn___Northern_Leaf_Blight',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Cherry___healthy',
#  'Apple___Apple_scab',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Corn___Common_rust',
#  'Background_without_leaves',
#  'Peach___Bacterial_spot',
#  'Pepper,_bell___Bacterial_spot',
# ...
